# %% [markdown]
# <a href="https://colab.research.google.com/github/Megu2024/Project/blob/main/Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gradient Descent:-
#           Gradient descent is an optimization algorithm which is commonly-used to train machine learning models and neural networks. It trains machine learning models by minimizing errors between predicted and actual results.
#           At each step it moves in the direction of the negative gradient (steepest descent) of a function, gradually reducing the function’s value.
#           in machine‑learning and statistics we rarely know model parameters analytically; instead we define a loss‑function and let gradient descent search for the parameters that minimise that loss.

# %% [markdown]
# The given function is f(x)=cos(2πx)+x^2.
# The code below evaluates the gradient analytically using the formula,
# f
# ′
#  (x)=−2πsin(2πx)+2x
#  The algorithm starts with an initial guess of
# 𝑥
# 0
# =
# 1.5
#  and uses a learning rate α=0.05. At each iteration, it updates the value of
# 𝑥
#  using the gradient descent rule:
#  x
# k+1
# ​
#  =x
# k
# ​
#  −α⋅f
# ′
#  (x
# k
# ​
#  )
#
# This means the algorithm takes small steps in the direction of the negative gradient to minimize the function. The process continues until one of two stopping conditions is met: either the change between consecutive steps becomes smaller than
# 10
# −
# 6
#  , indicating convergence, or the maximum number of iterations (60) is reached.

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(x):
    return np.cos(2 * np.pi * x) + x**2

def f_prime(x):
    return -2 * np.pi * np.sin(2 * np.pi * x) + 2 * x
alpha = 0.05
max_iters = 60
tol = 1e-6
x = 1.5
path = [x]
for _ in range(max_iters):
    grad = f_prime(x)
    new_x = x - alpha * grad
    path.append(new_x)
    if abs(new_x - x) < tol:
        break
    x = new_x
xs = np.linspace(-2, 2, 400)
ys = f(xs)
plt.figure(figsize=(8, 5))
plt.plot(xs, ys, label="f(x) = cos(2πx) + x²")
plt.plot(path, [f(p) for p in path], marker='o', linestyle='-', label="Gradient‑descent path")
plt.title("Gradient Descent on f(x) = cos(2πx) + x²")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.show()
